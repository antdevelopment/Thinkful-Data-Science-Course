# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline

# %% [markdown]
# # Relationships between bank client attributes

# %%
bank_marketing = pd.read_csv('bank-full.csv', sep=';')

# %%
bank_marketing.head(10)
# Out:
#    age           job   marital  education default  balance housing loan  \
# 0   58    management   married   tertiary      no     2143     yes   no
# 1   44    technician    single  secondary      no       29     yes   no
# 2   33  entrepreneur   married  secondary      no        2     yes  yes
# 3   47   blue-collar   married    unknown      no     1506     yes   no
# 4   33       unknown    single    unknown      no        1      no   no
# 5   35    management   married   tertiary      no      231     yes   no
# 6   28    management    single   tertiary      no      447     yes  yes
# 7   42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8   58       retired   married    primary      no      121     yes   no
# 9   43    technician    single  secondary      no      593     yes   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# ...

# %% [markdown]
# ## Plot client attributes against each other

# %%
# Plot age against all continuous attributes. Not sorted in order - this isn't a histogram. However, maybe sorting can give weird predictive power.

# age vs. balance
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.age, bank_marketing.balance)
plt.xlabel('Ages', fontsize=20)
plt.ylabel('Balance', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.age, bank_marketing.balance)[0,1])

# age vs. day
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.age, bank_marketing.day)
plt.xlabel('Ages', fontsize=20)
plt.ylabel('Day', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.age, bank_marketing.day)[0,1])

# age vs. duration
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.age, bank_marketing.duration)
plt.xlabel('Ages', fontsize=20)
plt.ylabel('Duration', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.age, bank_marketing.duration)[0,1])
# Out:
# corr coef:  0.748118149235
# corr coef:  0.97294852506
# corr coef:  0.909574413267

# %%
# Plot balance against all continuous attributes. Not sorted in order - this isn't a histogram. However, maybe sorting can give weird predictive power.

# balance vs. age
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.balance, bank_marketing.age)
plt.xlabel('Balance', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.balance, bank_marketing.age)[0,1])

# balance vs. day
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.balance, bank_marketing.day)
plt.xlabel('Balance', fontsize=20)
plt.ylabel('Day', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.balance, bank_marketing.day)[0,1])

# balance vs. duration
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.balance, bank_marketing.duration)
plt.xlabel('Balance', fontsize=20)
plt.ylabel('Duration', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.balance, bank_marketing.duration)[0,1])
# Out:
# corr coef:  0.0977827393713
# corr coef:  0.00450258512972
# corr coef:  0.0215603804947

# %%
# Plot day against all continuous attributes. Not sorted in order - this isn't a histogram. However, maybe sorting can give weird predictive power.

# day vs. age
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.day, bank_marketing.age)
plt.xlabel('Day', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.day, bank_marketing.age)[0,1])

# day vs. balance
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.day, bank_marketing.balance)
plt.xlabel('Day', fontsize=20)
plt.ylabel('Balance', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.day, bank_marketing.balance)[0,1])

# day vs. duration
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.day, bank_marketing.duration)
plt.xlabel('Day', fontsize=20)
plt.ylabel('Duration', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.day, bank_marketing.duration)[0,1])
# Out:
# corr coef:  -0.00912004563355
# corr coef:  0.00450258512972
# corr coef:  -0.0302063411387

# %%
# Plot duration against all continuous attributes. Not sorted in order - this isn't a histogram. However, maybe sorting can give weird predictive power.

# duration vs. age
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.duration, bank_marketing.age)
plt.xlabel('Duration', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.duration, bank_marketing.age)[0,1])

# duration vs. balance
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.duration, bank_marketing.balance)
plt.xlabel('Duration', fontsize=20)
plt.ylabel('Balance', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.duration, bank_marketing.balance)[0,1])

# duration vs. day
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.duration, bank_marketing.day)
plt.xlabel('Duration', fontsize=20)
plt.ylabel('Day', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.duration, bank_marketing.day)[0,1])
# Out:
# corr coef:  -0.00464842847062
# corr coef:  0.0215603804947
# corr coef:  -0.0302063411387

# %% [markdown]
# ## Sort attribute values and plot against another sorted attributes

# %%
# Plot sorted age against all continuous attributes. Client attributes have been uncoupled.
bank_marketing.age.values.sort()
bank_marketing.balance.values.sort()
bank_marketing.day.values.sort()
bank_marketing.duration.values.sort()
# age vs. balance
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.age, bank_marketing.balance)
plt.xlabel('Ages', fontsize=20)
plt.ylabel('Balance', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.age, bank_marketing.balance)[0,1])

# age vs. day
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.age, bank_marketing.day)
plt.xlabel('Ages', fontsize=20)
plt.ylabel('Day', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.age, bank_marketing.day)[0,1])

# age vs. duration
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.age, bank_marketing.duration)
plt.xlabel('Ages', fontsize=20)
plt.ylabel('Duration', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.age, bank_marketing.duration)[0,1])
# Out:
# corr coef:  0.748118149235
# corr coef:  0.97294852506
# corr coef:  0.909574413267

# %%
# Plot sorted balance against all continuous attributes. Client attributes have been uncoupled.

# balance vs. age
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.balance, bank_marketing.age)
plt.xlabel('Balance', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.balance, bank_marketing.age)[0,1])

# balance vs. day
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.balance, bank_marketing.day)
plt.xlabel('Balance', fontsize=20)
plt.ylabel('Day', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.balance, bank_marketing.day)[0,1])

# balance vs. duration
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.balance, bank_marketing.duration)
plt.xlabel('Balance', fontsize=20)
plt.ylabel('Duration', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.balance, bank_marketing.duration)[0,1])
# Out:
# corr coef:  0.748118149235
# corr coef:  0.603904773985
# corr coef:  0.940603497016

# %%
# Plot sorted day against all continuous attributes. Client attributes have been uncoupled.

# day vs. age
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.day, bank_marketing.age)
plt.xlabel('Day', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.day, bank_marketing.age)[0,1])

# day vs. balance
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.day, bank_marketing.balance)
plt.xlabel('Day', fontsize=20)
plt.ylabel('Balance', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.day, bank_marketing.balance)[0,1])

# day vs. duration
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.day, bank_marketing.duration)
plt.xlabel('Day', fontsize=20)
plt.ylabel('Duration', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.day, bank_marketing.duration)[0,1])
# Out:
# corr coef:  0.97294852506
# corr coef:  0.603904773985
# corr coef:  0.809392112149

# %%
# Plot sorted duration against all continuous attributes. Client attributes have been uncoupled.

# duration vs. age
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.duration, bank_marketing.age)
plt.xlabel('Duration', fontsize=20)
plt.ylabel('Age', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.duration, bank_marketing.age)[0,1])

# duration vs. balance
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.duration, bank_marketing.balance)
plt.xlabel('Duration', fontsize=20)
plt.ylabel('Balance', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.duration, bank_marketing.balance)[0,1])

# duration vs. day
plt.figure(figsize=(10, 5))
plt.scatter(bank_marketing.duration, bank_marketing.day)
plt.xlabel('Duration', fontsize=20)
plt.ylabel('Day', fontsize=20)
plt.show()
print('corr coef: ', np.corrcoef(bank_marketing.duration, bank_marketing.day)[0,1])
# Out:
# corr coef:  0.909574413267
# corr coef:  0.940603497016
# corr coef:  0.809392112149
