# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Prompt
#
# Data cleaning is definitely a "practice makes perfect" skill. Using this dataset of article open-access prices paid by the WELLCOME Trust between 2012 and 2013, determine the five most common journals and the total articles for each. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal . You will need to do considerable data cleaning in order to extract accurate estimates. For a real bonus round, identify the open access prices paid by subject area.

# %%
wellcome = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding='latin1')
print(wellcome.dtypes)
wellcome.columns = ['id', 'publisher', 'journal', 'title', 'cost']
wellcome.head()
# Out:
# PMID/PMCID                                             object
# Publisher                                              object
# Journal title                                          object
# Article title                                          object
# COST (£) charged to Wellcome (inc VAT when charged)    object
# dtype: object
#                       id publisher                 journal  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                                title      cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
wellcome.describe()
# Out:
#                        id publisher   journal  \
# count                1928      2127      2126
# unique               1880       299       984
# top     Not yet available  Elsevier  PLoS One
# freq                    7       387        92
#
#                                                     title      cost
# count                                                2127      2127
# unique                                               2126      1402
# top     Exclusive breastfeeding, diarrhoel morbidity a...  £2040.00
# freq                                                    2        94

# %%
# Ensure every element in the DataFrame is a string
wellcome = wellcome.applymap(str)

# Maximize proportion of alphanumeric characters
wellcome = wellcome.applymap(lambda item: ''.join(item.split('\n')))
wellcome = wellcome.applymap(lambda item: item.replace(':', ''))
wellcome = wellcome.applymap(lambda item: item.replace('(', ''))
wellcome = wellcome.applymap(lambda item: item.replace(')', ''))
wellcome = wellcome.applymap(lambda item: item.replace(',', ''))
wellcome = wellcome.applymap(lambda item: item.replace('-', ''))
wellcome = wellcome.applymap(lambda item: item.replace('\n', ''))
wellcome = wellcome.applymap(lambda item: item.replace('[', ''))
wellcome = wellcome.applymap(lambda item: item.replace(']', ''))
wellcome = wellcome.applymap(lambda item: item.replace('/', ''))
wellcome = wellcome.applymap(lambda item: item.replace('?', ''))

# Lowercase every entry
wellcome = wellcome.applymap(lambda item: item.lower())

# Filter out records which have a float64 type NaN as an ID or blank
wellcome = wellcome[wellcome.id.map(lambda item: item != 'nan')]
wellcome = wellcome[wellcome.id.map(lambda item: item != '')]

# Filter ID's which are only made of text
wellcome = wellcome[wellcome.id.map(lambda item: item.isalpha() == False)]

# Remove currency sign from cost variable
wellcome.cost = wellcome.cost.map(lambda item: item.replace('£', ''))
wellcome.cost = wellcome.cost.map(lambda item: item.replace('$', ''))
wellcome = wellcome[wellcome.cost.map(lambda item: item != '')]

# Convert cost variable to Pandas float type
wellcome.cost = wellcome.cost.astype(dtype='float64')

# Remove periods in journal variable
wellcome.journal = wellcome.journal.map(lambda item: item.replace('.', ''))

# %% [markdown]
# ## Top 5 journals and article count

# %%
# Create new variable for journal groupings
journals = wellcome.groupby('journal', as_index=True)

# Display ranking
journals.title.count().nlargest(5)
# Out:
# journal
# plos one                           187
# journal of biological chemistry     52
# neuroimage                          27
# plos pathogens                      24
# nucleic acids research              23
# Name: title, dtype: int64

# %% [markdown]
# ## Journal cost mean, median, and standard deviation

# %% [markdown]
# ### Mean

# %%
journals.mean().sort_values('cost', ascending=False)
# Out:
#                                                              cost
# journal
# journal of paediatric urology                       999999.000000
# the journal of cognitive neuroscience               999999.000000
# experimental cell research                          999999.000000
# oxford university press                             999999.000000
# qualitative research                                999999.000000
# poned1217947                                        999999.000000
# molecluar & cellular endocrinology                  999999.000000
# pmedicined1203130                                   999999.000000
# expert reviews in molecular medicine                999999.000000
# genetics in medicine                                999999.000000
# frontiers in cognition                              999999.000000
# vision research                                     500727.590000
# molecular cell                                      402355.042000
# embo reports                                        335413.000000
# jnl biological chemistry                            333805.013333
# journal of neurochemistry                           251578.532500
# trials                                              250908.975000
# cell                                                202537.214000
# cerebral cortex                                     201647.800000
# history of the human sciences                       201535.800000
# bmc genomics                                        200908.500000
# pnas                                                167303.490000
# journal of cell science                             144634.142857
# journal of physiology                               144567.644286
# plos computational biology                          126371.306250
# plosone                                             111883.790000
# plos pathogens                                       84775.044583
# human molecular genetics                             60737.514706
# nature communications                                55600.705263
# plos genetics                                        45049.888696
# ...                                                           ...
# frontiers in inflammation                              687.790000
# j org chem                                             685.880000
# biophysical journal                                    676.763333
# acs nano                                               668.140000
# biochemistry                                           665.640000
# journal of allergy                                     655.850000
# acta dermato venereologica                             653.960000
# pnas usa                                               651.580000
# evidence ethos and experiment the anthropology ...     651.250000
# mol pharm                                              649.330000
# international journal of rheumatology                  626.000000
# frontiers in neurorobotics                             625.200000
# journal of parasitology research                       623.950000
# proceddings of the national academy of sciences...     619.830000
# journal of medical virology                            612.590000
# autophagy                                              601.100000
# proceedings of the national academy of sciences...     584.675000
# theranostics                                           543.290000
# journal of visualized experiements                     517.500000
# epigentics                                             508.660000
# rna biology                                            490.123333
# epigenetics                                            487.900000
# j infect dis                                           378.780000
# haematologicathe haematology journal                   378.700000
# frontiers in genetics                                  346.250000
# cell adhesion and migration                            321.460000
# journal of medicinal chemistry                         321.120000
# essays in biochemistry                                 270.000000
# channels                                               159.740000
# veterinary research                                      9.930000
#
# [836 rows x 1 columns]

# %% [markdown]
# ### Median

# %%
journals.median().sort_values('cost', ascending=False)
# Out:
#                                                           cost
# journal
# pmedicined1203130                                   999999.000
# expert reviews in molecular medicine                999999.000
# frontiers in cognition                              999999.000
# the journal of cognitive neuroscience               999999.000
# experimental cell research                          999999.000
# journal of paediatric urology                       999999.000
# qualitative research                                999999.000
# molecluar & cellular endocrinology                  999999.000
# genetics in medicine                                999999.000
# oxford university press                             999999.000
# poned1217947                                        999999.000
# vision research                                     500727.590
# public service review                                 6000.000
# the lancet neurology                                  5760.000
# the lancet                                            4560.000
# cell host & microbe                                   4226.040
# curr biol                                             4151.770
# molecular cell                                        4148.390
# cell journal                                          4041.050
# cell                                                  3948.420
# immunity                                              3934.750
# neuron                                                3915.310
# cell metabolism                                       3904.460
# structure                                             3895.640
# cell press  cell reports                              3884.400
# developmental cell                                    3877.480
# current biology                                       3843.740
# cell host and microbe                                 3838.880
# cell reports                                          3836.320
# antimicrobial agfents and chemotherapy                3750.050
# ...                                                        ...
# frontiers in inflammation                              687.790
# j org chem                                             685.880
# biophysical journal                                    675.290
# acs nano                                               668.140
# biochemistry                                           665.640
# journal of allergy                                     655.850
# acta dermato venereologica                             653.960
# pnas usa                                               651.580
# evidence ethos and experiment the anthropology ...     651.250
# mol pharm                                              649.330
# international journal of rheumatology                  626.000
# frontiers in neurorobotics                             625.200
# journal of parasitology research                       623.950
# proceddings of the national academy of sciences...     619.830
# journal of medical virology                            612.590
# autophagy                                              601.100
# proceedings of the national academy of sciences...     584.675
# theranostics                                           543.290
# journal of visualized experiements                     517.500
# epigentics                                             508.660
# rna biology                                            494.960
# epigenetics                                            487.900
# j infect dis                                           378.780
# haematologicathe haematology journal                   378.700
# frontiers in genetics                                  346.250
# cell adhesion and migration                            321.460
# journal of medicinal chemistry                         321.120
# essays in biochemistry                                 270.000
# channels                                               159.740
# veterinary research                                      9.930
#
# [836 rows x 1 columns]

# %% [markdown]
# ### Standard deviation

# %%
journals.std().dropna()
# Out:
#                                                              cost
# journal
# acs chemical biology                                   500.670917
# acs nano                                                35.708892
# acta crystallographica section f structural bio...      15.605847
# acta neuropathologica                                   68.759063
# addiction                                              306.481292
# age                                                    237.785868
# aids                                                   281.067979
# aids care                                              126.415851
# aids uk                                                  0.000000
# alimentrary pharmacology & therapeutics                  0.000000
# american journal of epidemiology                       196.299092
# american journal of human genetics                     703.501205
# american journal of preventive medicine                  0.000000
# american journal of transplantation                    278.022730
# american journal of tropical medicine & hygiene          2.852110
# analytical chemistry                                   838.678951
# angewandte chemie international edition                  0.000000
# animal behaviour                                         7.071068
# annals of neurology                                    424.183550
# annals of neurology                                      0.000000
# antimicrobial agents and chemotherapy                  115.343350
# antioxidants and redox signaling                       598.707312
# archives of disease in childhood                       173.205081
# arthritis & rheumatism                                 353.553391
# arthritis and rheumatism                                 0.000000
# asian journal of psychiatry                            288.980399
# behavior research and therapy                           87.172124
# behavioral neuroscience                                109.112900
# behaviour research and therapy                           0.000000
# biochemical and biophysical research communicat...     545.179328
# ...                                                           ...
# rna                                                    139.667731
# rna biology                                             85.387799
# schizophrenia bulletin                                   5.303301
# schizophrenia research                                   0.000000
# scientific reports                                       0.000000
# social cognitive and affective neuroscience              0.000000
# social history of medicine                               0.000000
# social psychiatry and psychiatric epidemiol              0.000000
# social psychiatry and psychiatric epidemiology         172.267124
# social science and medicine                            600.217876
# sociology of health & illness                           59.453538
# stem cells                                             147.406037
# structure                                              166.835165
# the american journal of human genetics                 868.682815
# the biochemical journal                                  0.000000
# the embo journal                                      1103.086579
# the faseb journal                                       48.692031
# the journal of biological chemistry                    138.729897
# the journal of neuroscience                            591.763523
# the lancet                                             339.411255
# thorax                                                   0.000000
# traffic                                                357.639588
# translational psychiatry                                 0.000000
# trends in genetics                                       3.995153
# trials                                              499393.359606
# tropical medicine and international health             170.521422
# tuberculosis                                           228.133861
# vaccine                                                394.821486
# virology                                               697.850753
# vision research                                     706076.399327
#
# [286 rows x 1 columns]

# %% [markdown]
# ## For a real bonus round, identify the open access prices paid by subject area.

# %%
# Defining grouping function based on EDA.
# The journal keywords were explored on articles costing >= mean + std
def subject_area(element):
    if 'pathogen' in element or 'disease' in element or 'disorder' in element:
        return 'disease'
    elif 'gene' in element or 'geno' in element:
        return 'genetics'
    elif 'bio' in element or 'cell' in element or 'mole' in element:
        return 'biology'
    elif 'chem' in element:
        return 'chemistry'
    elif 'cog' in element or 'neuro' in element:
        return 'neuroscience'
    elif 'plos' in element or 'qualitative' in element or 'oxford' in element or 'human' in element or 'embo' in element or 'ology' in element:
        return 'general science'
    else:
        return 'other'

# Calculating cost per journal subject area
journals.sum().groupby(subject_area, as_index=True).sum()
# Out:
#                         cost
# biology          10766401.42
# chemistry         1088349.04
# disease           2398302.21
# general science  14826061.29
# genetics          4236081.11
# neuroscience      2301768.25
# other             8185695.47
