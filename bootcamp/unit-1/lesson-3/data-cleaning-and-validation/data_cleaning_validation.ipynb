# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Prompt
#
# Data cleaning is definitely a "practice makes perfect" skill. Using this dataset of article open-access prices paid by the WELLCOME Trust between 2012 and 2013, determine the five most common journals and the total articles for each. Next, calculate the mean, median, and standard deviation of the open-access cost per article for each journal . You will need to do considerable data cleaning in order to extract accurate estimates. For a real bonus round, identify the open access prices paid by subject area.

# %%
wellcome = pd.read_csv('WELLCOME_APCspend2013_forThinkful.csv', encoding='latin1')
print(wellcome.dtypes)
wellcome.columns = ['id', 'publisher', 'journal', 'title', 'cost']
wellcome.head()
# Out:
# PMID/PMCID                                             object
# Publisher                                              object
# Journal title                                          object
# Article title                                          object
# COST (£) charged to Wellcome (inc VAT when charged)    object
# dtype: object
#                       id publisher                 journal  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                                title      cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
wellcome.describe()
# Out:
#                 id publisher   journal  \
# count         1928      2127      2126
# unique        1880       299       984
# top     In Process  Elsevier  PLoS One
# freq             7       387        92
#
#                                                     title      cost
# count                                                2127      2127
# unique                                               2126      1402
# top     Exclusive breastfeeding, diarrhoel morbidity a...  £2040.00
# freq                                                    2        94

# %%
# Ensure every element in the DataFrame is a string
wellcome = wellcome.applymap(str)
wellcome2 = wellcome
# Remove all whitespace and maximize proportion of alphanumeric characters
wellcome = wellcome.applymap(lambda item: ''.join(item.split(' ')))
wellcome = wellcome.applymap(lambda item: ''.join(item.split('\n')))
wellcome = wellcome.applymap(lambda item: item.replace(':', ''))
wellcome = wellcome.applymap(lambda item: item.replace('(', ''))
wellcome = wellcome.applymap(lambda item: item.replace(')', ''))
wellcome = wellcome.applymap(lambda item: item.replace(',', ''))
wellcome = wellcome.applymap(lambda item: item.replace('-', ''))
wellcome = wellcome.applymap(lambda item: item.replace('\n', ''))
wellcome = wellcome.applymap(lambda item: item.replace('[', ''))
wellcome = wellcome.applymap(lambda item: item.replace(']', ''))
wellcome = wellcome.applymap(lambda item: item.replace('/', ''))
wellcome = wellcome.applymap(lambda item: item.replace('?', ''))

# Lowercase every entry
wellcome = wellcome.applymap(lambda item: item.lower())

# Filter out records which have a float64 type NaN as an ID or blank
wellcome = wellcome[wellcome.id.map(lambda item: item != 'nan')]
wellcome = wellcome[wellcome.id.map(lambda item: item != '')]

# Filter ID's which are only made of text
wellcome = wellcome[wellcome.id.map(lambda item: item.isalpha() == False)]

# Remove currency sign from cost variable
wellcome.cost = wellcome.cost.map(lambda item: item.replace('£', ''))
wellcome.cost = wellcome.cost.map(lambda item: item.replace('$', ''))
wellcome = wellcome[wellcome.cost.map(lambda item: item != '')]

# Convert cost variable to Pandas float type
wellcome.cost = wellcome.cost.astype(dtype='float64')

# Remove periods in journal variable
wellcome.journal = wellcome.journal.map(lambda item: item.replace('.', ''))

# %% [markdown]
# ## Top 5 journals and article count

# %%
# Create new variable for journal groupings
journals = wellcome.groupby('journal', as_index=True)

# Display ranking
journals.title.count().nlargest(5)
# Out:
# journal
# plosone                         194
# journalofbiologicalchemistry     52
# neuroimage                       27
# nucleicacidsresearch             25
# plospathogens                    24
# Name: title, dtype: int64

# %% [markdown]
# ## Journal cost mean, median, and standard deviation

# %% [markdown]
# ### Mean

# %%
journals.mean().sort_values('cost', ascending=False)
# Out:
#                                                              cost
# journal
# poned1217947                                        999999.000000
# experimentalcellresearch                            999999.000000
# expertreviewsinmolecularmedicine                    999999.000000
# frontiersincognition                                999999.000000
# geneticsinmedicine                                  999999.000000
# journalofpaediatricurology                          999999.000000
# molecluar&cellularendocrinology                     999999.000000
# oxforduniversitypress                               999999.000000
# thejournalofcognitiveneuroscience                   999999.000000
# pmedicined1203130                                   999999.000000
# visionresearch                                      500727.590000
# molecularcell                                       402355.042000
# emboreports                                         335413.000000
# jnlbiologicalchemistry                              333805.013333
# cell                                                202537.214000
# journalofneurochemistry                             201664.874000
# cerebralcortex                                      201647.800000
# historyofthehumansciences                           201535.800000
# trials                                              200960.180000
# bmcgenomics                                         200908.500000
# pnas                                                167303.490000
# journalofcellscience                                144634.142857
# journalofphysiology                                 144567.644286
# ploscomputationalbiology                            126371.306250
# plospathogens                                        84775.044583
# humanmoleculargenetics                               60737.514706
# naturecommunications                                 55600.705263
# plosgenetics                                         45049.888696
# plosone                                              43120.830825
# journalofbiologicalchemistry                         20630.090385
# ...                                                           ...
# frontlinegastroenterology                              720.000000
# internationaljournalofbehavioralnutritionandphy...     719.970000
# frontiersinconsciousnessresearch                       711.110000
# frontiersininflammation                                687.790000
# proceedingsofthenationalacademyofsciencesoftheu...     686.450000
# jorgchem                                               685.880000
# biophysicaljournal                                     676.763333
# acsnano                                                668.140000
# biochemistry                                           665.640000
# journalofallergy                                       655.850000
# actadermatovenereologica                               653.960000
# pnasusa                                                651.580000
# molpharm                                               649.330000
# internationaljournalofrheumatology                     626.000000
# frontiersinneurorobotics                               625.200000
# journalofparasitologyresearch                          623.950000
# proceddingsofthenationalacademyofsciencesofusa         619.830000
# autophagy                                              601.100000
# theranostics                                           543.290000
# journalofvisualizedexperiements                        517.500000
# epigentics                                             508.660000
# rnabiology                                             490.123333
# epigenetics                                            487.900000
# jinfectdis                                             378.780000
# haematologicathehaematologyjournal                     378.700000
# frontiersingenetics                                    346.250000
# celladhesionandmigration                               321.460000
# essaysinbiochemistry                                   270.000000
# channels                                               159.740000
# veterinaryresearch                                       9.930000
#
# [790 rows x 1 columns]

# %% [markdown]
# ### Median

# %%
journals.median().sort_values('cost', ascending=False)
# Out:
#                                                          cost
# journal
# molecluar&cellularendocrinology                     999999.00
# frontiersincognition                                999999.00
# experimentalcellresearch                            999999.00
# poned1217947                                        999999.00
# pmedicined1203130                                   999999.00
# journalofpaediatricurology                          999999.00
# oxforduniversitypress                               999999.00
# expertreviewsinmolecularmedicine                    999999.00
# geneticsinmedicine                                  999999.00
# thejournalofcognitiveneuroscience                   999999.00
# visionresearch                                      500727.59
# publicservicereview                                   6000.00
# thelancetneurology                                    5760.00
# thelancet                                             4560.00
# cellhost&microbe                                      4226.04
# currbiol                                              4151.77
# molecularcell                                         4148.39
# celljournal                                           4041.05
# cell                                                  3948.42
# immunity                                              3934.75
# neuron                                                3915.31
# cellmetabolism                                        3904.46
# structure                                             3895.64
# cellpresscellreports                                  3884.40
# developmentalcell                                     3877.48
# currentbiology                                        3843.74
# cellhostandmicrobe                                    3838.88
# cellreports                                           3836.32
# antimicrobialagfentsandchemotherapy                   3750.05
# lancetglobalhealth                                    3678.78
# ...                                                       ...
# frontlinegastroenterology                              720.00
# internationaljournalofbehavioralnutritionandphy...     719.97
# frontiersinconsciousnessresearch                       711.11
# frontiersininflammation                                687.79
# jorgchem                                               685.88
# biophysicaljournal                                     675.29
# acsnano                                                668.14
# biochemistry                                           665.64
# journalofallergy                                       655.85
# actadermatovenereologica                               653.96
# pnasusa                                                651.58
# molpharm                                               649.33
# internationaljournalofrheumatology                     626.00
# frontiersinneurorobotics                               625.20
# journalofparasitologyresearch                          623.95
# proceddingsofthenationalacademyofsciencesofusa         619.83
# proceedingsofthenationalacademyofsciencesoftheu...     601.70
# autophagy                                              601.10
# theranostics                                           543.29
# journalofvisualizedexperiements                        517.50
# epigentics                                             508.66
# rnabiology                                             494.96
# epigenetics                                            487.90
# jinfectdis                                             378.78
# haematologicathehaematologyjournal                     378.70
# frontiersingenetics                                    346.25
# celladhesionandmigration                               321.46
# essaysinbiochemistry                                   270.00
# channels                                               159.74
# veterinaryresearch                                       9.93
#
# [790 rows x 1 columns]

# %% [markdown]
# ### Standard deviation

# %%
journals.std(ddof=0)
# Out:
#                                                              cost
# journal
# academyofnutritionanddietetics                           0.000000
# acschemicalbiology                                     433.593733
# acschemicalneuroscience                                  0.000000
# acsnano                                                 25.250000
# actacrystallographicasectiond                            0.000000
# actacrystallographicasectiondbiologicalcrystall...       1.160000
# actacrystallographicasectionfstructuralbiologya...      11.035000
# actacrystallographyd                                     0.000000
# actad                                                    0.000000
# actadermatovenereologica                                 0.000000
# actadiabetologica                                        0.000000
# actaf                                                    0.000000
# actaneuropathol                                          0.000000
# actaneuropathologica                                    48.620000
# actaopthalmologica                                       0.000000
# actaphysiol                                              0.000000
# addiction                                                0.000000
# age                                                    168.140000
# ageandageing                                             0.000000
# agingcell                                                0.000000
# aids                                                   229.491044
# aidsbehav                                                0.000000
# aidscare                                                78.507709
# aidsjournal                                              0.000000
# aidsresearchandtherapy                                   0.000000
# aidsuk                                                   0.000000
# alcoholandalcoholism                                     0.000000
# alimentrarypharmacology&therapeutics                     0.000000
# americaljournalofpsychiatry                              0.000000
# americanchemicalsociety                                  0.000000
# ...                                                           ...
# thorax                                                   0.000000
# thoraxaninternationaljournalforrespiratorymedicine       0.000000
# ticksandtickbornediseases                                0.000000
# tissueengineeringparta                                   0.000000
# traffic                                                319.882572
# transactionsoftheroyalsocietyoftropicalmedicine...       0.000000
# translationalpsychiatry                                  0.000000
# trendsincognitivescience                                 0.000000
# trendsingenetics                                         2.825000
# trendsinmicrobiology                                     0.000000
# trendsinmolecularmedicine                                0.000000
# trendsinneuroscience                                     0.000000
# trials                                              399519.417624
# tropicalanimalhealth&production                          0.000000
# tropicalmedicineandinternationalhealth                 152.518997
# tropmedinthealth                                         0.000000
# tuberculosis                                           161.315000
# urolithiasis                                             0.000000
# vaccine                                                353.139073
# vascularpharmacology                                     0.000000
# veterinarymicrobiology                                   0.000000
# veterinaryparasitology                                   0.000000
# veterinaryrecord                                         0.000000
# veterinaryresearch                                       0.000000
# virology                                               493.455000
# virologyjournal                                          0.000000
# virusresearch                                            0.000000
# visionresearch                                      499271.410000
# visualneuroscience                                       0.000000
# zoonosesandpublichealth                                  0.000000
#
# [790 rows x 1 columns]

# %% [markdown]
# ## For a real bonus round, identify the open access prices paid by subject area. (unfinished)

# %%
# Remove all whitespace and maximize proportion of alphanumeric characters
wellcome2 = wellcome2.applymap(lambda item: ''.join(item.split('\n')))
wellcome2 = wellcome2.applymap(lambda item: item.replace(':', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace('(', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace(')', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace(',', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace('-', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace('\n', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace('[', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace(']', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace('/', ''))
wellcome2 = wellcome2.applymap(lambda item: item.replace('?', ''))

# Lowercase every entry
wellcome2 = wellcome2.applymap(lambda item: item.lower())

# Filter out records which have a float64 type NaN as an ID or blank
wellcome2 = wellcome2[wellcome2.id.map(lambda item: item != 'nan')]
wellcome2 = wellcome2[wellcome2.id.map(lambda item: item != '')]

# Filter ID's which are only made of text
wellcome2 = wellcome2[wellcome2.id.map(lambda item: item.isalpha() == False)]

# Remove currency sign from cost variable
wellcome2.cost = wellcome2.cost.map(lambda item: item.replace('£', ''))
wellcome2.cost = wellcome2.cost.map(lambda item: item.replace('$', ''))
wellcome2 = wellcome2[wellcome2.cost.map(lambda item: item != '')]

# Convert cost variable to Pandas float type
wellcome2.cost = wellcome2.cost.astype(dtype='float64')

# Remove periods in journal variable
wellcome2.journal = wellcome2.journal.map(lambda item: item.replace('.', ''))

# split elements apart at spaces
wellcome2.journal = wellcome2.journal.map(lambda item: item.split(' '))
wellcome2.title = wellcome2.title.map(lambda item: item.split(' '))
